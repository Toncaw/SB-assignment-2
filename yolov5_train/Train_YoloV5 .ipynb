# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Sun Dec 12 12:19:00 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'   yolov5

# %% [markdown]
# **Yolov5 setup**

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10191, done.
# remote: Total 10191 (delta 0), reused 0 (delta 0), pack-reused 10191
# Receiving objects: 100% (10191/10191), 10.47 MiB | 10.29 MiB/s, done.
# Resolving deltas: 100% (7062/7062), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.0/78.2 GB disk)

# %%
# Create folder on google drive so that we can save there the weights
# !mkdir "/mydrive/yolov5"
# Out:
# mkdir: cannot create directory ‘/mydrive/yolov5’: File exists

# %% [markdown]
# **4) Extract Images**
#
# The images need to be inside a zip archive called "images.zip" and they need to be inside the folder "yolov3" on Google Drive

# %%
# !unzip /mydrive/yolov5/train_data.zip -d data/
# Out:
# Archive:  /mydrive/yolov5/train_data.zip
#    creating: data/train_data/images/
#    creating: data/train_data/images/train/
#   inflating: data/train_data/images/train/0001.png
#   inflating: data/train_data/images/train/0002.png
#   inflating: data/train_data/images/train/0003.png
#   inflating: data/train_data/images/train/0004.png
#   inflating: data/train_data/images/train/0005.png
#   inflating: data/train_data/images/train/0006.png
#   inflating: data/train_data/images/train/0007.png
#   inflating: data/train_data/images/train/0008.png
#   inflating: data/train_data/images/train/0009.png
#   inflating: data/train_data/images/train/0010.png
#   inflating: data/train_data/images/train/0011.png
#   inflating: data/train_data/images/train/0012.png
#   inflating: data/train_data/images/train/0013.png
#   inflating: data/train_data/images/train/0014.png
#   inflating: data/train_data/images/train/0015.png
#   inflating: data/train_data/images/train/0016.png
# ...

# %% [markdown]
# **6) Start the training**

# %%
# %ls
# Out:
# CONTRIBUTING.md  Dockerfile  LICENSE    requirements.txt*  tutorial.ipynb
# data/            export.py   models/    setup.cfg          utils/
# detect.py        hubconf.py  README.md  train.py           val.py

# %%
# Start the training
# !python train.py --img 480 --batch 16 --epochs 300 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=480, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# %cp -r /content/yolov5/runs/train/exp3/ /content/gdrive/MyDrive/yolov5/
